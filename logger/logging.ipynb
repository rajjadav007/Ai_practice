# %%
import logging

# %%
logger1=logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

## crate a logger for module 2

logger2=logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%m:%S'
)

# %%
logger1.debug("this is debug message for module1")
logger2.warning("this is warning message for module1")
logger2.error("this is debug message for module1")
# Out:
# 2026-07-13 14:07:49 - module1 - DEBUG - this is debug message for module1
# 2026-07-13 14:07:49 - module2 - WARNING - this is warning message for module1
# 2026-07-13 14:07:49 - module2 - ERROR - this is debug message for module1
